# %%
# Mobile Recharge Validation System
def validate_recharge():
    valid_plans = [199, 299, 399, 599]

    while True:
        amount = int(input("Enter recharge amount (₹): "))

        if amount < 50:
            print("Recharge amount should be at least ₹50. Please try again.")

        elif amount not in valid_plans:
            print("Invalid plan selected.")
            print("Available plans are:", valid_plans)

        else:
            print("Recharge successful! ")
            break
validate_recharge()
# Out:
# Enter recharge amount (₹): 122
# Invalid plan selected.
# Available plans are: [199, 299, 399, 599]
# Enter recharge amount (₹): 199
# Recharge successful!

# %%
# Inventory Reorder Alert System
def inventory_alert(products):

    for product, quantity in products.items():

        if quantity < 15:
            print(f"{product} → Reorder Alert! (Current stock: {quantity})")
        else:
            print(f"{product} → Stock is sufficient. (Current stock: {quantity})")

inventory = {
    "Laptop": 10,
    "Mouse": 25,
    "Keyboard": 8,
    "Monitor": 20
}

inventory_alert(inventory)
# Out:
# Laptop → Reorder Alert! (Current stock: 10)
# Mouse → Stock is sufficient. (Current stock: 25)
# Keyboard → Reorder Alert! (Current stock: 8)
# Monitor → Stock is sufficient. (Current stock: 20)

# %%
#Student Result Processing System
def process_result(marks):

    total = 0

    for mark in marks:
        total += mark

    average = total / len(marks)

    print("Average Marks:", average)

    if average >= 50:
        return "Pass"
    else:
        return "Fail"

student_marks = [60, 45, 70, 50]
result = process_result(student_marks)
print("Final Result:", result)
# Out:
# Average Marks: 56.25
# Final Result: Pass

# %%
# Cab Fare Estimator with Retry Option
def calculate_fare(distance, is_peak):

    base_fare = 50
    fare = base_fare + (12 * distance)

    if is_peak.lower() == "yes":
        fare = fare + (fare * 0.25)

    return fare


while True:
    try:
        distance = float(input("Enter distance (in km): "))
        peak = input("Is it peak hour? (yes/no): ")

        total_fare = calculate_fare(distance, peak)
        print("Total Fare: ₹", total_fare)

        retry = input("Do you want to calculate again? (yes/no): ")
        if retry.lower() != "yes":
            break

    except ValueError:
        print("Please enter valid input.")
# Out:
# Enter distance (in km): 20
# Is it peak hour? (yes/no): yes
# Total Fare: ₹ 362.5
# Do you want to calculate again? (yes/no): yes
# Enter distance (in km): 20
# Is it peak hour? (yes/no): no
# Total Fare: ₹ 290.0
# Do you want to calculate again? (yes/no): no

# %%
# Employee Attendance Eligibility
def check_attendance(attendance_list):

    present_days = 0
    for status in attendance_list:
        if status == "P":
            present_days += 1

    percentage = (present_days / len(attendance_list)) * 100

    print("Attendance Percentage:", percentage, "%")

    if percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"

attendance_data = ["P", "P", "A", "P", "P", "A", "P", "P"]
eligibility = check_attendance(attendance_data)
print("Status:", eligibility)
# Out:
# Attendance Percentage: 75.0 %
# Status: Eligible

# %%
# Password Strength Checker
def check_password(password):

    special_characters = "@#$"
    has_digit = False
    has_special = False

    if len(password) < 8:
        return "Password is too short. Minimum 8 characters required."

    for char in password:
        if char.isdigit():
            has_digit = True
        if char in special_characters:
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    else:
        return "Weak Password (Must contain at least one digit and one special character @#$)"

user_password = input("Enter your password: ")
print(check_password(user_password))
# Out:
# Enter your password: Priya
# Password is too short. Minimum 8 characters required.

# %%
# Password Strength Checker
def check_password(password):

    special_characters = "@#$"
    has_digit = False
    has_special = False

    if len(password) < 8:
        return "Password must be at least 8 characters long."

    for char in password:
        if char.isdigit():
            has_digit = True
        if char in special_characters:
            has_special = True

    if has_digit and has_special:
        return "Strong"
    else:
        return "Password must contain at least one digit and one special character (@#$)."

while True:
    user_password = input("Enter your password: ")

    result = check_password(user_password)

    if result == "Strong":
        print("Strong Password")
        break
    else:
        print("Weak Password ")
        print(result)
        print("Please try again.\n")
# Out:
# Enter your password: Priya
# Weak Password
# Password must be at least 8 characters long.
# Please try again.
#
# Enter your password: Priya@123
# Strong Password
